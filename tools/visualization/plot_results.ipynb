# %% [markdown]
# # Plot Finance Monte Carlo

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
import os

# %%
project_home = Path(os.curdir).absolute().parent.parent

# %% [markdown]
# ## Plot a single run

# %%
run_dir = project_home / "output/default"
df = pd.read_csv(run_dir / "timeseries_data.csv", float_precision="round_trip", index_col = "Date")

# %%
plot_time_series(
    df["person.cash_on_hand"],
    title="Cash on Hand",
    save_path=run_dir / "visualization/cash_on_hand.png",
)

# %%
plot_time_series(
    df,
    title="All Signals",
    save_path=run_dir / "visualization/all_signals.png",
    use_logy=True
)

# %% [markdown]
# ## Plot a Monte Carlo

# %%
# Plot monte carlo
mc_dir = project_home / "output/default"
